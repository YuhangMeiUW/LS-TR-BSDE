# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

plt.rc('font', size=13)          # controls default text sizes
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
# dim_list = [2, 4, 6, 8, 10, 20]
# LSV_MSE = np.load("LSV_MSE.npy")
# TRCo_MSE = np.load("TRCo_MSE.npy")
# LSCo_MSE = np.load("LSCo_MSE.npy")
# TRV_MSE = np.load("TRV_MSE.npy")

# mean_LSV_MSE = np.mean(LSV_MSE, axis=0)
# mean_TRCo_MSE = np.mean(TRCo_MSE, axis=0)
# mean_LSCo_MSE = np.mean(LSCo_MSE, axis=0)
# mean_TRV_MSE = np.mean(TRV_MSE, axis=0)
# # std_LSV_MSE = np.std(LSV_MSE, axis=0)
# # std_TRCo_MSE = np.std(TRCo_MSE, axis=0)
# # std_LSCo_MSE = np.std(LSCo_MSE, axis=0)
# # std_TRV_MSE = np.std(TRV_MSE, axis=0)
# min_LSV_MSE = np.min(LSV_MSE, axis=0)
# min_TRCo_MSE = np.min(TRCo_MSE, axis=0)
# min_LSCo_MSE = np.min(LSCo_MSE, axis=0)
# min_TRV_MSE = np.min(TRV_MSE, axis=0)
# max_LSV_MSE = np.max(LSV_MSE, axis=0)
# max_TRCo_MSE = np.max(TRCo_MSE, axis=0)
# max_LSCo_MSE = np.max(LSCo_MSE, axis=0)
# max_TRV_MSE = np.max(TRV_MSE, axis=0)
# plt.figure()
# # plt.fill_between(dim_list, mean_LSV_MSE - std_LSV_MSE, mean_LSV_MSE + std_LSV_MSE, color="C0", alpha=0.3)
# # plt.fill_between(dim_list, mean_TRCo_MSE - std_TRCo_MSE, mean_TRCo_MSE + std_TRCo_MSE, color="C1", alpha=0.3)
# # plt.fill_between(dim_list, mean_LSCo_MSE - std_LSCo_MSE, mean_LSCo_MSE + std_LSCo_MSE, color="C2", alpha=0.3)
# # plt.fill_between(dim_list, mean_TRV_MSE - std_TRV_MSE, mean_TRV_MSE + std_TRV_MSE, color="C3", alpha=0.3)
# plt.plot(dim_list, mean_LSV_MSE, label="Least Square Value", color="C0")
# plt.plot(dim_list, mean_TRCo_MSE, label="Time Reversal Costate", color="C1")
# plt.plot(dim_list, mean_LSCo_MSE, label="Least Square Costate", color="C2")
# plt.plot(dim_list, mean_TRV_MSE, label="Time Reversal Value", color="C3")
# plt.fill_between(dim_list, min_LSV_MSE, max_LSV_MSE, color="C0", alpha=0.3)
# plt.fill_between(dim_list, min_TRCo_MSE, max_TRCo_MSE, color="C1", alpha=0.3)
# plt.fill_between(dim_list, min_LSCo_MSE, max_LSCo_MSE, color="C2", alpha=0.3)
# plt.fill_between(dim_list, min_TRV_MSE, max_TRV_MSE, color="C3", alpha=0.3)
# plt.xlabel("Dimension")
# plt.ylabel("MSE")
# plt.yscale("log")
# plt.xticks(dim_list)
# plt.legend()
# plt.title('T={}, dt={}, sample={}'.format(4, 0.02, 500))
# plt.show()

# %% [markdown]
# Plot for G matrix

# %%
G_ref = np.load("G_ref_T4_dt002_N2000.npy")
G_LSV = np.load("G_LSV.npy")
G_TRCo = np.load("G_TRCo.npy")
G_LSCo = np.load("G_LSCo.npy")
G_TRV = np.load("G_TRV.npy")
steps = int(4/0.02)

# %%
plt.figure()
plt.plot(np.arange(steps)*0.02, G_ref[:,0,0], color="C0", label=r"$G_{11}$")
plt.plot(np.arange(steps)*0.02, G_ref[:,0,1], color="C1", label=r"$G_{12}$")
plt.plot(np.arange(steps)*0.02, G_ref[:,1,0], color="C2", label=r"$G_{21}$")
plt.plot(np.arange(steps)*0.02, G_ref[:,1,1], color="C3", label=r"$G_{22}$")
plt.plot(np.arange(steps)*0.02, G_LSV[:,0,0], color="C0", linestyle="--")
plt.plot(np.arange(steps)*0.02, G_LSV[:,0,1], color="C1", linestyle="--")
plt.plot(np.arange(steps)*0.02, G_LSV[:,1,0], color="C2", linestyle="--")
plt.plot(np.arange(steps)*0.02, G_LSV[:,1,1], color="C3", linestyle="--")
plt.xlabel("Time", fontsize=14)
plt.title("LS-V", fontsize=14)
# plt.legend(loc = 'upper center', fontsize=11, ncol=4, bbox_to_anchor=(0.5, 1.2))
plt.legend(loc = 'lower right', fontsize=11, bbox_to_anchor=(1, 0.15))
plt.show()

# %%
plt.figure()
plt.plot(np.arange(steps)*0.02, G_ref[:,0,0], color="C0")
plt.plot(np.arange(steps)*0.02, G_ref[:,0,1], color="C1")
plt.plot(np.arange(steps)*0.02, G_ref[:,1,0], color="C2")
plt.plot(np.arange(steps)*0.02, G_ref[:,1,1], color="C3")
plt.plot(np.arange(steps)*0.02, G_TRCo[:,0,0], color="C0", linestyle="--")
plt.plot(np.arange(steps)*0.02, G_TRCo[:,0,1], color="C1", linestyle="--")
plt.plot(np.arange(steps)*0.02, G_TRCo[:,1,0], color="C2", linestyle="--")
plt.plot(np.arange(steps)*0.02, G_TRCo[:,1,1], color="C3", linestyle="--")
plt.xlabel("Time", fontsize=14)
plt.title("TR-C", fontsize=14)
plt.show()

# %%
plt.figure()
plt.plot(np.arange(steps)*0.02, G_ref[:,0,0], color="C0")
plt.plot(np.arange(steps)*0.02, G_ref[:,0,1], color="C1")
plt.plot(np.arange(steps)*0.02, G_ref[:,1,0], color="C2")
plt.plot(np.arange(steps)*0.02, G_ref[:,1,1], color="C3")
plt.plot(np.arange(steps)*0.02, G_LSCo[:,0,0], color="C0", linestyle="--")
plt.plot(np.arange(steps)*0.02, G_LSCo[:,0,1], color="C1", linestyle="--")
plt.plot(np.arange(steps)*0.02, G_LSCo[:,1,0], color="C2", linestyle="--")
plt.plot(np.arange(steps)*0.02, G_LSCo[:,1,1], color="C3", linestyle="--")
plt.xlabel("Time", fontsize=14)
plt.title("LS-C", fontsize=14)
plt.show()

# %%
plt.figure()
plt.plot(np.arange(steps)*0.02, G_ref[:,0,0], color="C0")
plt.plot(np.arange(steps)*0.02, G_ref[:,0,1], color="C1")
plt.plot(np.arange(steps)*0.02, G_ref[:,1,0], color="C2")
plt.plot(np.arange(steps)*0.02, G_ref[:,1,1], color="C3")
plt.plot(np.arange(steps)*0.02, G_TRV[:,0,0], color="C0", linestyle="--")
plt.plot(np.arange(steps)*0.02, G_TRV[:,0,1], color="C1", linestyle="--")
plt.plot(np.arange(steps)*0.02, G_TRV[:,1,0], color="C2", linestyle="--")
plt.plot(np.arange(steps)*0.02, G_TRV[:,1,1], color="C3", linestyle="--")
plt.xlabel("Time", fontsize=14)
plt.title("TR-V", fontsize=14)
plt.show()

# %%
LSV_J = np.load("LSV_J.npy")
TRCo_J = np.load("TRCo_J.npy")
LSCo_J = np.load("LSCo_J.npy")
TRV_J = np.load("TRV_J.npy")
LSV_time = np.loadtxt("LSV_time.txt")
TRCo_time = np.loadtxt("TRCo_time.txt")
LSCo_time = np.loadtxt("LSCo_time.txt")
TRV_time = np.loadtxt("TRV_time.txt")
LSV_mean_time = np.mean(LSV_time)
TRCo_mean_time = np.mean(TRCo_time)
LSCo_mean_time = np.mean(LSCo_time)
TRV_mean_time = np.mean(TRV_time)
plt.figure()
plt.plot(LSV_J[0:16], color="C0", label="LS-V J", linestyle="--")
plt.plot(LSCo_J[0:16], color="C2", label="LS-C J")
plt.plot(TRV_J[0:16], color="C3", label="TR-V J", marker="o", linestyle="", markersize=4)
plt.plot(TRCo_J[0:16], color="C1", label="TR-C J")
# plt.xticks([np.arange(16)])
plt.xlabel("Iteration", fontsize=15)
plt.title("Cost", fontsize=15)
plt.legend()
plt.show()

# %%
dt_list = [0.004, 0.02, 0.05, 0.1, 0.2, 0.3, 0.4]
LSV_MSE_dt = np.load("LSV_MSE_dt.npy")
TRCo_MSE_dt = np.load("TRCo_MSE_dt.npy")
LSCo_MSE_dt = np.load("LSCo_MSE_dt.npy")
TRV_MSE_dt = np.load("TRV_MSE_dt.npy")
mean_LSV_MSE_dt = np.mean(LSV_MSE_dt, axis=0)
mean_TRCo_MSE_dt = np.mean(TRCo_MSE_dt, axis=0)
mean_LSCo_MSE_dt = np.mean(LSCo_MSE_dt, axis=0)
mean_TRV_MSE_dt = np.mean(TRV_MSE_dt, axis=0)
min_LSV_MSE_dt = np.min(LSV_MSE_dt, axis=0)
min_TRCo_MSE_dt = np.min(TRCo_MSE_dt, axis=0)
min_LSCo_MSE_dt = np.min(LSCo_MSE_dt, axis=0)
min_TRV_MSE_dt = np.min(TRV_MSE_dt, axis=0)
max_LSV_MSE_dt = np.max(LSV_MSE_dt, axis=0)
max_TRCo_MSE_dt = np.max(TRCo_MSE_dt, axis=0)
max_LSCo_MSE_dt = np.max(LSCo_MSE_dt, axis=0)
max_TRV_MSE_dt = np.max(TRV_MSE_dt, axis=0)
plt.figure()
plt.plot(dt_list, mean_LSV_MSE_dt, color="C0", label="LS-V")
plt.plot(dt_list, mean_LSCo_MSE_dt, color="C2", label="LS-C")
plt.plot(dt_list, mean_TRV_MSE_dt, color="C3", label="TR-V")
plt.plot(dt_list, mean_TRCo_MSE_dt, color="C1", label="TR-C")
# for i in range(15):
#     plt.plot(LSV_MSE_dt[i,:], color="C0", alpha=0.2)
#     plt.plot(TRCo_MSE_dt[i,:], color="C1", alpha=0.2)
#     plt.plot(LSCo_MSE_dt[i,:], color="C2", alpha=0.2)
#     plt.plot(TRV_MSE_dt[i,:], color="C3", alpha=0.2)
plt.fill_between(dt_list, min_LSV_MSE_dt, max_LSV_MSE_dt, color="C0", alpha=0.3)
plt.fill_between(dt_list, min_TRCo_MSE_dt, max_TRCo_MSE_dt, color="C1", alpha=0.3)
plt.fill_between(dt_list, min_LSCo_MSE_dt, max_LSCo_MSE_dt, color="C2", alpha=0.3)
plt.fill_between(dt_list, min_TRV_MSE_dt, max_TRV_MSE_dt, color="C3", alpha=0.3)
plt.xlabel("Time step size", fontsize=14)
plt.ylabel("MSE", fontsize=14)
plt.yscale("log")
plt.legend()
plt.show()

# %%
print(LSCo_MSE_dt[:,-1])
# print(LSCo_MSE_dt)
# Out:
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]

# %%
sample_list = [10, 50, 100, 500, 1000, 2000, 4000]  
LSV_MSE_sample = np.load("LSV_MSE_sample.npy")
TRCo_MSE_sample = np.load("TRCo_MSE_sample.npy")
LSCo_MSE_sample = np.load("LSCo_MSE_sample.npy")
TRV_MSE_sample = np.load("TRV_MSE_sample.npy")
mean_LSV_MSE_sample = np.mean(LSV_MSE_sample, axis=0)
mean_TRCo_MSE_sample = np.mean(TRCo_MSE_sample, axis=0)
mean_LSCo_MSE_sample = np.mean(LSCo_MSE_sample, axis=0)
mean_TRV_MSE_sample = np.mean(TRV_MSE_sample, axis=0)
min_LSV_MSE_sample = np.min(LSV_MSE_sample, axis=0)
min_TRCo_MSE_sample = np.min(TRCo_MSE_sample, axis=0)
min_LSCo_MSE_sample = np.min(LSCo_MSE_sample, axis=0)
min_TRV_MSE_sample = np.min(TRV_MSE_sample, axis=0)
max_LSV_MSE_sample = np.max(LSV_MSE_sample, axis=0)
max_TRCo_MSE_sample = np.max(TRCo_MSE_sample, axis=0)
max_LSCo_MSE_sample = np.max(LSCo_MSE_sample, axis=0)
max_TRV_MSE_sample = np.max(TRV_MSE_sample, axis=0)
plt.figure()
plt.plot(sample_list, mean_LSV_MSE_sample, color="C0", label="LS-V")
plt.plot(sample_list, mean_LSCo_MSE_sample, color="C2", label="LS-C")
plt.plot(sample_list, mean_TRV_MSE_sample, color="C3", label="TR-V")
plt.plot(sample_list, mean_TRCo_MSE_sample, color="C1", label="TR-C")
plt.fill_between(sample_list, min_LSV_MSE_sample, max_LSV_MSE_sample, color="C0", alpha=0.3)
plt.fill_between(sample_list, min_TRCo_MSE_sample, max_TRCo_MSE_sample, color="C1", alpha=0.3)
plt.fill_between(sample_list, min_LSCo_MSE_sample, max_LSCo_MSE_sample, color="C2", alpha=0.3)
plt.fill_between(sample_list, min_TRV_MSE_sample, max_TRV_MSE_sample, color="C3", alpha=0.3)
plt.xlabel("Sample size N", fontsize=14)
plt.ylabel("MSE", fontsize=14)
plt.yscale("log")
plt.xscale("log")
plt.legend(fontsize=11)
plt.show()

# %%
print(TRV_MSE_sample[:,0])
# Out:
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]

# %%
dim_list = [2, 4, 6, 8, 10, 20]
LSV_MSE_dim = np.load("LSV_MSE_exp15_N1000.npy")
TRCo_MSE_dim = np.load("TRCo_MSE_exp15_N1000.npy")
LSCo_MSE_dim = np.load("LSCo_MSE_exp15_N1000.npy")
TRV_MSE_dim = np.load("TRV_MSE_exp15_N1000.npy")
mean_LSV_MSE_dim = np.mean(LSV_MSE_dim, axis=0)
mean_TRCo_MSE_dim = np.mean(TRCo_MSE_dim, axis=0)
mean_LSCo_MSE_dim = np.mean(LSCo_MSE_dim, axis=0)
mean_TRV_MSE_dim = np.mean(TRV_MSE_dim, axis=0)
min_LSV_MSE_dim = np.min(LSV_MSE_dim, axis=0)
min_TRCo_MSE_dim = np.min(TRCo_MSE_dim, axis=0)
min_LSCo_MSE_dim = np.min(LSCo_MSE_dim, axis=0)
min_TRV_MSE_dim = np.min(TRV_MSE_dim, axis=0)
max_LSV_MSE_dim = np.max(LSV_MSE_dim, axis=0)
max_TRCo_MSE_dim = np.max(TRCo_MSE_dim, axis=0)
max_LSCo_MSE_dim = np.max(LSCo_MSE_dim, axis=0)
max_TRV_MSE_dim = np.max(TRV_MSE_dim, axis=0)
plt.figure()
plt.plot(dim_list, mean_LSV_MSE_dim, color="C0", label="LS-V")
plt.plot(dim_list, mean_LSCo_MSE_dim, color="C2", label="LS-C")
plt.plot(dim_list, mean_TRV_MSE_dim, color="C3", label="TR-V")
plt.plot(dim_list, mean_TRCo_MSE_dim, color="C1", label="TR-C")
plt.fill_between(dim_list, min_LSV_MSE_dim, max_LSV_MSE_dim, color="C0", alpha=0.3)
plt.fill_between(dim_list, min_TRCo_MSE_dim, max_TRCo_MSE_dim, color="C1", alpha=0.3)
plt.fill_between(dim_list, min_LSCo_MSE_dim, max_LSCo_MSE_dim, color="C2", alpha=0.3)
plt.fill_between(dim_list, min_TRV_MSE_dim, max_TRV_MSE_dim, color="C3", alpha=0.3)
plt.xlabel("Dimension", fontsize=14)
plt.ylabel("MSE", fontsize=14)
plt.yscale("log")
plt.xticks(dim_list)
plt.legend(fontsize=12)
plt.show()

# %%
TRV_MSE_dim[:,-1]
# Out:
# array([       nan, 0.00153221,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan, 0.00191488,        nan])

# %%
LSV_MSE_exp15 = np.load("LSV_MSE_T4_dt002_N2000_exp15.npy")
TRCo_MSE_exp15 = np.load("TRCo_MSE_T4_dt002_N2000_exp15.npy")
LSCo_MSE_exp15 = np.load("LSCo_MSE_T4_dt002_N2000_exp15.npy")
TRV_MSE_exp15 = np.load("TRV_MSE_T4_dt002_N2000_exp15.npy")
mean_LSV_MSE_exp15 = np.mean(LSV_MSE_exp15, axis=0)
mean_TRCo_MSE_exp15 = np.mean(TRCo_MSE_exp15, axis=0)
mean_LSCo_MSE_exp15 = np.mean(LSCo_MSE_exp15, axis=0)
mean_TRV_MSE_exp15 = np.mean(TRV_MSE_exp15, axis=0)
std_LSV_MSE_exp15 = np.std(LSV_MSE_exp15, axis=0)
std_TRCo_MSE_exp15 = np.std(TRCo_MSE_exp15, axis=0)
std_LSCo_MSE_exp15 = np.std(LSCo_MSE_exp15, axis=0)
std_TRV_MSE_exp15 = np.std(TRV_MSE_exp15, axis=0)
LSV_time_exp15 = np.loadtxt("LSV_time_exp15.txt")
TRCo_time_exp15 = np.loadtxt("TRCo_time_exp15.txt")
LSCo_time_exp15 = np.loadtxt("LSCo_time_exp15.txt")
TRV_time_exp15 = np.loadtxt("TRV_time_exp15.txt")
LSV_mean_time_exp15 = np.mean(LSV_time_exp15)
TRCo_mean_time_exp15 = np.mean(TRCo_time_exp15)
LSCo_mean_time_exp15 = np.mean(LSCo_time_exp15)
TRV_mean_time_exp15 = np.mean(TRV_time_exp15)
print(f'LSV time: {LSV_mean_time_exp15},LSV MSE: {mean_LSV_MSE_exp15}, std: {std_LSV_MSE_exp15}')
print(f'TRCo time: {TRCo_mean_time_exp15},TRCo MSE: {mean_TRCo_MSE_exp15}, std: {std_TRCo_MSE_exp15}')
print(f'LSCo time: {LSCo_mean_time_exp15},LSCo MSE: {mean_LSCo_MSE_exp15}, std: {std_LSCo_MSE_exp15}')
print(f'TRV time: {TRV_mean_time_exp15},TRV MSE: {mean_TRV_MSE_exp15}, std: {std_TRV_MSE_exp15}')
# Out:
# LSV time: 10.340846252441406,LSV MSE: [0.004529], std: [0.00193468]
# TRCo time: 10.042924133936564,TRCo MSE: [2.25473063e-06], std: [4.00947514e-07]
# LSCo time: 4.4558323383331295,LSCo MSE: [0.0047631], std: [0.00251065]
# TRV time: 13.126416397094726,TRV MSE: [0.00061456], std: [0.0001514]
